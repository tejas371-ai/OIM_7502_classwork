# %% [markdown]
# The first step is to install the pycaret library. Shown below is the code for default installation. This will not include all the optional dependencies, to install them, use pip install pycaret[full]

# %%
pip install pycaret
# Out:
# Requirement already satisfied: pycaret in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (3.3.2)
# Requirement already satisfied: ipython>=5.5.0 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from pycaret) (9.5.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from pycaret) (8.1.8)
# Requirement already satisfied: tqdm>=4.62.0 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from pycaret) (4.67.1)
# Requirement already satisfied: numpy<1.27,>=1.21 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from pycaret) (1.26.4)
# Requirement already satisfied: pandas<2.2.0 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from pycaret) (2.1.4)
# Requirement already satisfied: jinja2>=3 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from pycaret) (3.1.6)
# Requirement already satisfied: scipy<=1.11.4,>=1.6.1 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from pycaret) (1.11.4)
# Requirement already satisfied: joblib<1.4,>=1.2.0 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from pycaret) (1.3.2)
# Requirement already satisfied: scikit-learn>1.4.0 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from pycaret) (1.4.2)
# Requirement already satisfied: pyod>=1.1.3 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from pycaret) (2.0.5)
# Requirement already satisfied: imbalanced-learn>=0.12.0 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from pycaret) (0.14.0)
# Requirement already satisfied: category-encoders>=2.4.0 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from pycaret) (2.7.0)
# Requirement already satisfied: lightgbm>=3.0.0 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from pycaret) (4.6.0)
# Requirement already satisfied: numba>=0.55.0 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from pycaret) (0.62.1)
# Requirement already satisfied: requests>=2.27.1 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from pycaret) (2.32.5)
# Requirement already satisfied: psutil>=5.9.0 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from pycaret) (7.0.0)
# Requirement already satisfied: markupsafe>=2.0.1 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from pycaret) (3.0.2)
# Requirement already satisfied: importlib-metadata>=4.12.0 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from pycaret) (8.7.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from pycaret) (5.10.4)
# Requirement already satisfied: cloudpickle in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from pycaret) (3.1.1)
# Requirement already satisfied: deprecation>=2.1.0 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: xxhash in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from pycaret) (3.6.0)
# Requirement already satisfied: matplotlib<3.8.0 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from pycaret) (3.7.5)
# Requirement already satisfied: scikit-plot>=0.3.7 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: yellowbrick>=1.4 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from pycaret) (1.5)
# Requirement already satisfied: plotly>=5.14.0 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from pycaret) (6.3.1)
# Requirement already satisfied: kaleido>=0.2.1 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from pycaret) (1.1.0)
# Requirement already satisfied: schemdraw==0.15 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from pycaret) (0.15)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from pycaret) (0.11.0)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from pycaret) (0.14.5)
# Requirement already satisfied: sktime==0.26.0 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from pycaret) (0.26.0)
# Requirement already satisfied: tbats>=1.1.3 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: pmdarima>=2.0.4 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from pycaret) (2.0.4)
# Requirement already satisfied: packaging in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from sktime==0.26.0->pycaret) (25.0)
# Requirement already satisfied: scikit-base<0.8.0 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from sktime==0.26.0->pycaret) (0.7.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from matplotlib<3.8.0->pycaret) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from matplotlib<3.8.0->pycaret) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from matplotlib<3.8.0->pycaret) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from matplotlib<3.8.0->pycaret) (1.4.9)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from matplotlib<3.8.0->pycaret) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from matplotlib<3.8.0->pycaret) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from matplotlib<3.8.0->pycaret) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from pandas<2.2.0->pycaret) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from pandas<2.2.0->pycaret) (2025.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from scikit-learn>1.4.0->pycaret) (3.6.0)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from category-encoders>=2.4.0->pycaret) (1.0.2)
# Requirement already satisfied: zipp>=3.20 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from importlib-metadata>=4.12.0->pycaret) (3.23.0)
# Requirement already satisfied: colorama in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from ipython>=5.5.0->pycaret) (0.4.6)
# Requirement already satisfied: decorator in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from ipython>=5.5.0->pycaret) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from ipython>=5.5.0->pycaret) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from ipython>=5.5.0->pycaret) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from ipython>=5.5.0->pycaret) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from ipython>=5.5.0->pycaret) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from ipython>=5.5.0->pycaret) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from ipython>=5.5.0->pycaret) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from ipython>=5.5.0->pycaret) (5.14.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from ipython>=5.5.0->pycaret) (4.15.0)
# Requirement already satisfied: wcwidth in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.5.0->pycaret) (0.2.13)
# Requirement already satisfied: comm>=0.1.3 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.1)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (3.0.16)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.4)
# Requirement already satisfied: choreographer>=1.0.10 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from kaleido>=0.2.1->pycaret) (1.2.0)
# Requirement already satisfied: logistro>=1.0.8 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from kaleido>=0.2.1->pycaret) (2.0.1)
# Requirement already satisfied: orjson>=3.10.15 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from kaleido>=0.2.1->pycaret) (3.11.4)
# Requirement already satisfied: pytest-timeout>=2.4.0 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from kaleido>=0.2.1->pycaret) (2.4.0)
# Requirement already satisfied: simplejson>=3.19.3 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from choreographer>=1.0.10->kaleido>=0.2.1->pycaret) (3.20.2)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from nbformat>=4.2.0->pycaret) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from nbformat>=4.2.0->pycaret) (4.25.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from nbformat>=4.2.0->pycaret) (5.8.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.22.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret) (4.3.7)
# Requirement already satisfied: pywin32>=300 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret) (311)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from numba>=0.55.0->pycaret) (0.45.1)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from plotly>=5.14.0->pycaret) (2.10.1)
# Requirement already satisfied: dash>=2.11.0 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.2.0)
# Requirement already satisfied: tsdownsample>=0.1.3 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.1.4.1)
# Requirement already satisfied: Flask<3.2,>=1.0.4 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (3.1.2)
# Requirement already satisfied: Werkzeug<3.2 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (3.1.3)
# Requirement already satisfied: retrying in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.4.2)
# Requirement already satisfied: nest-asyncio in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.6.0)
# Requirement already satisfied: setuptools in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (80.9.0)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (8.3.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.0)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from pmdarima>=2.0.4->pycaret) (3.1.6)
# Requirement already satisfied: urllib3 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from pmdarima>=2.0.4->pycaret) (2.5.0)
# Requirement already satisfied: pytest>=7.0.0 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from pytest-timeout>=2.4.0->kaleido>=0.2.1->pycaret) (8.4.2)
# Requirement already satisfied: iniconfig>=1 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido>=0.2.1->pycaret) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido>=0.2.1->pycaret) (1.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from python-dateutil>=2.7->matplotlib<3.8.0->pycaret) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from requests>=2.27.1->pycaret) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from requests>=2.27.1->pycaret) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from requests>=2.27.1->pycaret) (2025.10.5)
# Requirement already satisfied: executing>=1.2.0 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from stack_data->ipython>=5.5.0->pycaret) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from stack_data->ipython>=5.5.0->pycaret) (3.0.0)
# Requirement already satisfied: pure_eval in c:\users\tejas\anaconda3\envs\pycaret_midterm\lib\site-packages (from stack_data->ipython>=5.5.0->pycaret) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # PyCaret Classification Quick Start Workflow
#
# This section outlines the minimum steps required to go from raw data to a fully trained machine learning model using the PyCaret Functional API. This demonstrates your Quick Start Capability.
#
# ### 1. Importing Libraries and Loading Data
#
# The first step in any PyCaret analysis is **importing the necessary functions** and loading the data using `get_data()`.
#
# ### 2. Setting Up the Experiment
#
# Next, we define our experiment using the `setup()` function. This is the most crucial step, as it handles all of the automatic **preprocessing, data cleaning, and data splitting**. We must specify the `target` column.
#
# ### 3. Experimentation and Model Comparison
#
# The most powerful function in Classification is `compare_models()`, which trains and evaluates a leaderboard of algorithms in a single line.
#
# ### 4. Finalization and Saving
#
# Finally, the best model can be saved using the `save_model` function. This saves the **complete pipeline** (preprocessing steps + model), fulfilling the **MLOps readiness** requirement.

# %% [markdown]
# ## Classification Module

# %%
# --- Imports for Functional and OOP API Access ---
from pycaret.datasets import get_data
from pycaret.classification import (
    setup,
    compare_models,
    predict_model,
    plot_model,
    save_model
)
from pycaret.classification import ClassificationExperiment # Required for OOP

print("--- Structured Classification Workflow ---")
# Out:
# --- Structured Classification Workflow ---

# %%
# 1. LOAD DATASET
data = get_data('bank')
print("\n[STEP 1] Data Loaded (Bank Marketing Data).")
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome deposit
# 0  unknown    5   may       261         1     -1         0  unknown      no
# 1  unknown    5   may       151         1     -1         0  unknown      no
# 2  unknown    5   may        76         1     -1         0  unknown      no
# 3  unknown    5   may        92         1     -1         0  unknown      no
# 4  unknown    5   may       198         1     -1         0  unknown      no
# [STEP 1] Data Loaded (Bank Marketing Data).

# %%
# 2. FUNCTIONAL API DEMO (Quick Check)
print("\n[STEP 2] Functional API Demo: Running Setup for Quick Check...")
# The functional API is fine for a quick benchmark/check
# *** FIXED TARGET: 'deposit' ***
s_functional = setup(
    data=data,
    target='deposit',
    session_id=7502,
    normalize=True,
    verbose=False # Set to False to prevent clash with OOP's setup output
)
print("[STEP 2] Functional Setup Complete. Now Switching to OOP API for Full Workflow.")
# Out:
# [STEP 2] Functional API Demo: Running Setup for Quick Check...
# [STEP 2] Functional Setup Complete. Now Switching to OOP API for Full Workflow.

# %%
# 3. OOP API (SETUP - For the Main Workflow)
# Initialize the OOP Experiment object. This is a clean slate.
exp = ClassificationExperiment()
print("\n[STEP 3] Initializing OOP API Setup (Full Workflow)...")

# We run setup again on the OOP object for the main analysis flow.
exp.setup(
    data=data,
    target='deposit',
    session_id=7502,
    normalize=True,
    verbose=True # Set to True to display the main Setup Grid
)
# Out:
# [STEP 3] Initializing OOP API Setup (Full Workflow)...
# <style type="text/css">
# #T_f6ebc_row10_col1, #T_f6ebc_row16_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f6ebc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f6ebc_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f6ebc_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f6ebc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f6ebc_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f6ebc_row0_col1" class="data row0 col1" >7502</td>
#     </tr>
#     <tr>
#       <th id="T_f6ebc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f6ebc_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f6ebc_row1_col1" class="data row1 col1" >deposit</td>
#     </tr>
#     <tr>
#       <th id="T_f6ebc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f6ebc_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_f6ebc_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_f6ebc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f6ebc_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_f6ebc_row3_col1" class="data row3 col1" >no: 0, yes: 1</td>
#     </tr>
#     <tr>
#       <th id="T_f6ebc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f6ebc_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_f6ebc_row4_col1" class="data row4 col1" >(45211, 17)</td>
#     </tr>
#     <tr>
#       <th id="T_f6ebc_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f6ebc_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_f6ebc_row5_col1" class="data row5 col1" >(45211, 49)</td>
#     </tr>
#     <tr>
#       <th id="T_f6ebc_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f6ebc_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_f6ebc_row6_col1" class="data row6 col1" >(31647, 49)</td>
#     </tr>
#     <tr>
#       <th id="T_f6ebc_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f6ebc_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_f6ebc_row7_col1" class="data row7 col1" >(13564, 49)</td>
#     </tr>
#     <tr>
#       <th id="T_f6ebc_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f6ebc_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_f6ebc_row8_col1" class="data row8 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_f6ebc_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f6ebc_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_f6ebc_row9_col1" class="data row9 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_f6ebc_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f6ebc_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_f6ebc_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f6ebc_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f6ebc_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_f6ebc_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_f6ebc_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f6ebc_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_f6ebc_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_f6ebc_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f6ebc_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_f6ebc_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_f6ebc_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_f6ebc_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_f6ebc_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_f6ebc_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_f6ebc_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_f6ebc_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f6ebc_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_f6ebc_row16_col0" class="data row16 col0" >Normalize</td>
#       <td id="T_f6ebc_row16_col1" class="data row16 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f6ebc_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_f6ebc_row17_col0" class="data row17 col0" >Normalize method</td>
#       <td id="T_f6ebc_row17_col1" class="data row17 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_f6ebc_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_f6ebc_row18_col0" class="data row18 col0" >Fold Generator</td>
#       <td id="T_f6ebc_row18_col1" class="data row18 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_f6ebc_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_f6ebc_row19_col0" class="data row19 col0" >Fold Number</td>
#       <td id="T_f6ebc_row19_col1" class="data row19 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_f6ebc_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_f6ebc_row20_col0" class="data row20 col0" >CPU Jobs</td>
#       <td id="T_f6ebc_row20_col1" class="data row20 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_f6ebc_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_f6ebc_row21_col0" class="data row21 col0" >Use GPU</td>
#       <td id="T_f6ebc_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f6ebc_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_f6ebc_row22_col0" class="data row22 col0" >Log Experiment</td>
#       <td id="T_f6ebc_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f6ebc_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_f6ebc_row23_col0" class="data row23 col0" >Experiment Name</td>
#       <td id="T_f6ebc_row23_col1" class="data row23 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_f6ebc_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_f6ebc_row24_col0" class="data row24 col0" >USI</td>
#       <td id="T_f6ebc_row24_col1" class="data row24 col1" >fda3</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 4. COMPARE MODELS
print("\n[STEP 4] Comparing Models (Benchmarking all algorithms)...")
# We use the OOP method: exp.compare_models()
best_model = exp.compare_models(verbose=True)
print(f"\nModel Comparison Complete. Best Model: {type(best_model).__name__}")
# Out:
# [STEP 4] Comparing Models (Benchmarking all algorithms)...
# <style type="text/css">
# #T_c33b8 th {
#   text-align: left;
# }
# #T_c33b8_row0_col0, #T_c33b8_row1_col0, #T_c33b8_row1_col1, #T_c33b8_row1_col2, #T_c33b8_row1_col3, #T_c33b8_row1_col4, #T_c33b8_row1_col5, #T_c33b8_row1_col6, #T_c33b8_row1_col7, #T_c33b8_row2_col0, #T_c33b8_row2_col1, #T_c33b8_row2_col2, #T_c33b8_row2_col3, #T_c33b8_row2_col4, #T_c33b8_row2_col5, #T_c33b8_row2_col6, #T_c33b8_row2_col7, #T_c33b8_row3_col0, #T_c33b8_row3_col1, #T_c33b8_row3_col2, #T_c33b8_row3_col3, #T_c33b8_row3_col4, #T_c33b8_row3_col5, #T_c33b8_row3_col6, #T_c33b8_row3_col7, #T_c33b8_row4_col0, #T_c33b8_row4_col1, #T_c33b8_row4_col2, #T_c33b8_row4_col3, #T_c33b8_row4_col4, #T_c33b8_row4_col5, #T_c33b8_row4_col6, #T_c33b8_row4_col7, #T_c33b8_row5_col0, #T_c33b8_row5_col1, #T_c33b8_row5_col2, #T_c33b8_row5_col3, #T_c33b8_row5_col4, #T_c33b8_row5_col5, #T_c33b8_row5_col6, #T_c33b8_row5_col7, #T_c33b8_row6_col0, #T_c33b8_row6_col1, #T_c33b8_row6_col2, #T_c33b8_row6_col3, #T_c33b8_row6_col4, #T_c33b8_row6_col5, #T_c33b8_row6_col6, #T_c33b8_row6_col7, #T_c33b8_row7_col0, #T_c33b8_row7_col1, #T_c33b8_row7_col2, #T_c33b8_row7_col3, #T_c33b8_row7_col4, #T_c33b8_row7_col5, #T_c33b8_row7_col6, #T_c33b8_row7_col7, #T_c33b8_row8_col0, #T_c33b8_row8_col1, #T_c33b8_row8_col2, #T_c33b8_row8_col3, #T_c33b8_row8_col4, #T_c33b8_row8_col5, #T_c33b8_row8_col6, #T_c33b8_row8_col7, #T_c33b8_row9_col0, #T_c33b8_row9_col1, #T_c33b8_row9_col2, #T_c33b8_row9_col3, #T_c33b8_row9_col4, #T_c33b8_row9_col5, #T_c33b8_row9_col6, #T_c33b8_row9_col7, #T_c33b8_row10_col0, #T_c33b8_row10_col1, #T_c33b8_row10_col2, #T_c33b8_row10_col3, #T_c33b8_row10_col4, #T_c33b8_row10_col5, #T_c33b8_row10_col6, #T_c33b8_row10_col7, #T_c33b8_row11_col0, #T_c33b8_row11_col1, #T_c33b8_row11_col2, #T_c33b8_row11_col3, #T_c33b8_row11_col4, #T_c33b8_row11_col5, #T_c33b8_row11_col6, #T_c33b8_row11_col7, #T_c33b8_row12_col0, #T_c33b8_row12_col1, #T_c33b8_row12_col2, #T_c33b8_row12_col3, #T_c33b8_row12_col4, #T_c33b8_row12_col5, #T_c33b8_row12_col6, #T_c33b8_row12_col7, #T_c33b8_row13_col0, #T_c33b8_row13_col1, #T_c33b8_row13_col2, #T_c33b8_row13_col3, #T_c33b8_row13_col4, #T_c33b8_row13_col5, #T_c33b8_row13_col6, #T_c33b8_row13_col7 {
#   text-align: left;
# }
# #T_c33b8_row0_col1, #T_c33b8_row0_col2, #T_c33b8_row0_col3, #T_c33b8_row0_col4, #T_c33b8_row0_col5, #T_c33b8_row0_col6, #T_c33b8_row0_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_c33b8_row0_col8, #T_c33b8_row1_col8, #T_c33b8_row2_col8, #T_c33b8_row3_col8, #T_c33b8_row4_col8, #T_c33b8_row5_col8, #T_c33b8_row6_col8, #T_c33b8_row7_col8, #T_c33b8_row8_col8, #T_c33b8_row9_col8, #T_c33b8_row11_col8, #T_c33b8_row12_col8, #T_c33b8_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_c33b8_row10_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_c33b8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c33b8_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c33b8_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_c33b8_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_c33b8_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_c33b8_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_c33b8_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_c33b8_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_c33b8_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_c33b8_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c33b8_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_c33b8_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_c33b8_row0_col1" class="data row0 col1" >0.9086</td>
#       <td id="T_c33b8_row0_col2" class="data row0 col2" >0.9342</td>
#       <td id="T_c33b8_row0_col3" class="data row0 col3" >0.9086</td>
#       <td id="T_c33b8_row0_col4" class="data row0 col4" >0.9004</td>
#       <td id="T_c33b8_row0_col5" class="data row0 col5" >0.9030</td>
#       <td id="T_c33b8_row0_col6" class="data row0 col6" >0.5051</td>
#       <td id="T_c33b8_row0_col7" class="data row0 col7" >0.5115</td>
#       <td id="T_c33b8_row0_col8" class="data row0 col8" >0.3880</td>
#     </tr>
#     <tr>
#       <th id="T_c33b8_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_c33b8_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_c33b8_row1_col1" class="data row1 col1" >0.9055</td>
#       <td id="T_c33b8_row1_col2" class="data row1 col2" >0.9261</td>
#       <td id="T_c33b8_row1_col3" class="data row1 col3" >0.9055</td>
#       <td id="T_c33b8_row1_col4" class="data row1 col4" >0.8930</td>
#       <td id="T_c33b8_row1_col5" class="data row1 col5" >0.8938</td>
#       <td id="T_c33b8_row1_col6" class="data row1 col6" >0.4372</td>
#       <td id="T_c33b8_row1_col7" class="data row1 col7" >0.4590</td>
#       <td id="T_c33b8_row1_col8" class="data row1 col8" >0.6970</td>
#     </tr>
#     <tr>
#       <th id="T_c33b8_level0_row2" class="row_heading level0 row2" >gbc</th>
#       <td id="T_c33b8_row2_col0" class="data row2 col0" >Gradient Boosting Classifier</td>
#       <td id="T_c33b8_row2_col1" class="data row2 col1" >0.9047</td>
#       <td id="T_c33b8_row2_col2" class="data row2 col2" >0.9230</td>
#       <td id="T_c33b8_row2_col3" class="data row2 col3" >0.9047</td>
#       <td id="T_c33b8_row2_col4" class="data row2 col4" >0.8924</td>
#       <td id="T_c33b8_row2_col5" class="data row2 col5" >0.8944</td>
#       <td id="T_c33b8_row2_col6" class="data row2 col6" >0.4453</td>
#       <td id="T_c33b8_row2_col7" class="data row2 col7" >0.4619</td>
#       <td id="T_c33b8_row2_col8" class="data row2 col8" >0.9470</td>
#     </tr>
#     <tr>
#       <th id="T_c33b8_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_c33b8_row3_col0" class="data row3 col0" >Extra Trees Classifier</td>
#       <td id="T_c33b8_row3_col1" class="data row3 col1" >0.9004</td>
#       <td id="T_c33b8_row3_col2" class="data row3 col2" >0.9068</td>
#       <td id="T_c33b8_row3_col3" class="data row3 col3" >0.9004</td>
#       <td id="T_c33b8_row3_col4" class="data row3 col4" >0.8852</td>
#       <td id="T_c33b8_row3_col5" class="data row3 col5" >0.8864</td>
#       <td id="T_c33b8_row3_col6" class="data row3 col6" >0.3931</td>
#       <td id="T_c33b8_row3_col7" class="data row3 col7" >0.4178</td>
#       <td id="T_c33b8_row3_col8" class="data row3 col8" >0.7670</td>
#     </tr>
#     <tr>
#       <th id="T_c33b8_level0_row4" class="row_heading level0 row4" >lr</th>
#       <td id="T_c33b8_row4_col0" class="data row4 col0" >Logistic Regression</td>
#       <td id="T_c33b8_row4_col1" class="data row4 col1" >0.9002</td>
#       <td id="T_c33b8_row4_col2" class="data row4 col2" >0.9044</td>
#       <td id="T_c33b8_row4_col3" class="data row4 col3" >0.9002</td>
#       <td id="T_c33b8_row4_col4" class="data row4 col4" >0.8849</td>
#       <td id="T_c33b8_row4_col5" class="data row4 col5" >0.8863</td>
#       <td id="T_c33b8_row4_col6" class="data row4 col6" >0.3927</td>
#       <td id="T_c33b8_row4_col7" class="data row4 col7" >0.4169</td>
#       <td id="T_c33b8_row4_col8" class="data row4 col8" >0.8580</td>
#     </tr>
#     <tr>
#       <th id="T_c33b8_level0_row5" class="row_heading level0 row5" >lda</th>
#       <td id="T_c33b8_row5_col0" class="data row5 col0" >Linear Discriminant Analysis</td>
#       <td id="T_c33b8_row5_col1" class="data row5 col1" >0.9002</td>
#       <td id="T_c33b8_row5_col2" class="data row5 col2" >0.9049</td>
#       <td id="T_c33b8_row5_col3" class="data row5 col3" >0.9002</td>
#       <td id="T_c33b8_row5_col4" class="data row5 col4" >0.8899</td>
#       <td id="T_c33b8_row5_col5" class="data row5 col5" >0.8933</td>
#       <td id="T_c33b8_row5_col6" class="data row5 col6" >0.4529</td>
#       <td id="T_c33b8_row5_col7" class="data row5 col7" >0.4599</td
# Model Comparison Complete. Best Model: LGBMClassifier

# %%
# 5. ANALYSE MODEL (Diagnostics)
print("\n[STEP 5] Analyzing Model (Plotting AUC and Confusion Matrix)...")
# Analyze AUC curve using OOP method
exp.plot_model(best_model, plot='auc')
# Out:
# [STEP 5] Analyzing Model (Plotting AUC and Confusion Matrix)...

# %%
# Analyze Confusion Matrix using OOP method
exp.plot_model(best_model, plot='confusion_matrix')

# %%
# 6. PREDICTIONS
print("\n[STEP 6] Generating Predictions on Held-Out Test Set...")
# Predict on the held-out test set using OOP method
predictions = exp.predict_model(best_model)
print("\nPredictions on held-out set (first 5 rows):")
# Note: The original 'deposit' column is compared against the new 'prediction_label'
print(predictions[['deposit', 'prediction_label']].head())
# Out:
# [STEP 6] Generating Predictions on Held-Out Test Set...
# <style type="text/css">
# </style>
# <table id="T_3f02b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3f02b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3f02b_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_3f02b_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_3f02b_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_3f02b_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_3f02b_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_3f02b_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_3f02b_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3f02b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3f02b_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_3f02b_row0_col1" class="data row0 col1" >0.9098</td>
#       <td id="T_3f02b_row0_col2" class="data row0 col2" >0.9384</td>
#       <td id="T_3f02b_row0_col3" class="data row0 col3" >0.9098</td>
#       <td id="T_3f02b_row0_col4" class="data row0 col4" >0.9018</td>
#       <td id="T_3f02b_row0_col5" class="data row0 col5" >0.9044</td>
#       <td id="T_3f02b_row0_col6" class="data row0 col6" >0.5130</td>
#       <td id="T_3f02b_row0_col7" class="data row0 col7" >0.5189</td>
#     </tr>
#   </tbody>
# </table>
# Predictions on held-out set (first 5 rows):
#       deposit prediction_label
# 21939      no               no
# 40852      no              yes
# 8040       no               no
# 11699      no               no
# 9769       no               no

# %%
# 7. SAVE MODEL
print("\n[STEP 7] Saving Pipeline (MLOps Readiness)...")
# Save the final model and the entire preprocessing pipeline using OOP method
exp.save_model(best_model, 'pycaret_bank_final_pipeline')
print("\nModel saved successfully as 'pycaret_bank_final_pipeline.pkl'.")
# Out:
# [STEP 7] Saving Pipeline (MLOps Readiness)...
# Transformation Pipeline and Model Successfully Saved
#
# Model saved successfully as 'pycaret_bank_final_pipeline.pkl'.

# %% [markdown]
# ## Regresssion Module

# %%
# --- Imports for Functional and OOP API Access ---
from pycaret.datasets import get_data
from pycaret.regression import(
    setup,
    compare_models,
    predict_model,
    plot_model,
    save_model
)
from pycaret.regression import RegressionExperiment

print("--- Structured REGRESSION Workflow ---")
# Out:
# --- Structured REGRESSION Workflow ---

# %%
# 1. LOAD DATASET
# Load the diamond dataset for Regression (predicting continuous Price)
data = get_data('diamond')
print("\n[STEP 1] Data Loaded (Diamond Price Data).")
# Out:
#    Carat Weight    Cut Color Clarity Polish Symmetry Report  Price
# 0          1.10  Ideal     H     SI1     VG       EX    GIA   5169
# 1          0.83  Ideal     H     VS1     ID       ID   AGSL   3470
# 2          0.85  Ideal     H     SI1     EX       EX    GIA   3183
# 3          0.91  Ideal     E     SI1     VG       VG    GIA   4370
# 4          0.83  Ideal     G     SI1     EX       EX    GIA   3171
# [STEP 1] Data Loaded (Diamond Price Data).

# %%
# 2. FUNCTIONAL API DEMO (Quick Check)
print("\n[STEP 2] Functional API Demo: Running Setup for Quick Check...")
# The functional API is fine for a quick benchmark/check
s_functional = setup(
    data=data,
    target='Price',
    session_id=7502,
    normalize=True,
    verbose=False # Set to False to prevent clash with OOP's setup output
)
print("[STEP 2] Functional Setup Complete. Now Switching to OOP API for Full Workflow.")
# Out:
# [STEP 2] Functional API Demo: Running Setup for Quick Check...
# [STEP 2] Functional Setup Complete. Now Switching to OOP API for Full Workflow.

# %%
# 3. OOP API (SETUP - For the Main Workflow)
# Initialize the OOP Experiment object. This is a clean slate.
exp = RegressionExperiment() # NOTE: Initializing RegressionExperiment
print("\n[STEP 3] Initializing OOP API Setup (Full Workflow)...")

# We run setup again on the OOP object for the main analysis flow.
exp.setup(
    data=data,
    target='Price',
    session_id=7502,
    normalize=True,
    verbose=True # Set to True to display the main Setup Grid
)
# Out:
# [STEP 3] Initializing OOP API Setup (Full Workflow)...
# <style type="text/css">
# #T_d7921_row9_col1, #T_d7921_row15_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d7921">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d7921_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d7921_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d7921_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d7921_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d7921_row0_col1" class="data row0 col1" >7502</td>
#     </tr>
#     <tr>
#       <th id="T_d7921_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d7921_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d7921_row1_col1" class="data row1 col1" >Price</td>
#     </tr>
#     <tr>
#       <th id="T_d7921_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d7921_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_d7921_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_d7921_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d7921_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_d7921_row3_col1" class="data row3 col1" >(6000, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_d7921_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d7921_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_d7921_row4_col1" class="data row4 col1" >(6000, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_d7921_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d7921_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_d7921_row5_col1" class="data row5 col1" >(4200, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_d7921_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d7921_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_d7921_row6_col1" class="data row6 col1" >(1800, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_d7921_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d7921_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_d7921_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d7921_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d7921_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_d7921_row8_col1" class="data row8 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_d7921_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d7921_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_d7921_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d7921_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d7921_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_d7921_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_d7921_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d7921_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_d7921_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_d7921_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d7921_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_d7921_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_d7921_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d7921_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_d7921_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_d7921_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d7921_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_d7921_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_d7921_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d7921_row15_col0" class="data row15 col0" >Normalize</td>
#       <td id="T_d7921_row15_col1" class="data row15 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d7921_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_d7921_row16_col0" class="data row16 col0" >Normalize method</td>
#       <td id="T_d7921_row16_col1" class="data row16 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_d7921_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_d7921_row17_col0" class="data row17 col0" >Fold Generator</td>
#       <td id="T_d7921_row17_col1" class="data row17 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_d7921_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_d7921_row18_col0" class="data row18 col0" >Fold Number</td>
#       <td id="T_d7921_row18_col1" class="data row18 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_d7921_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_d7921_row19_col0" class="data row19 col0" >CPU Jobs</td>
#       <td id="T_d7921_row19_col1" class="data row19 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_d7921_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_d7921_row20_col0" class="data row20 col0" >Use GPU</td>
#       <td id="T_d7921_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d7921_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_d7921_row21_col0" class="data row21 col0" >Log Experiment</td>
#       <td id="T_d7921_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d7921_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_d7921_row22_col0" class="data row22 col0" >Experiment Name</td>
#       <td id="T_d7921_row22_col1" class="data row22 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_d7921_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_d7921_row23_col0" class="data row23 col0" >USI</td>
#       <td id="T_d7921_row23_col1" class="data row23 col1" >5a41</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 4. COMPARE MODELS
print("\n[STEP 4] Comparing Models (Benchmarking all algorithms)...")
# We use the OOP method: exp.compare_models(). Metrics will now be R2, MAE, RMSE, etc.
best_model = exp.compare_models(verbose=True)
print(f"\nModel Comparison Complete. Best Model: {type(best_model).__name__}")
# Out:
# [STEP 4] Comparing Models (Benchmarking all algorithms)...
# <style type="text/css">
# #T_2c5e5 th {
#   text-align: left;
# }
# #T_2c5e5_row0_col0, #T_2c5e5_row0_col1, #T_2c5e5_row0_col5, #T_2c5e5_row0_col6, #T_2c5e5_row1_col0, #T_2c5e5_row1_col1, #T_2c5e5_row1_col2, #T_2c5e5_row1_col3, #T_2c5e5_row1_col4, #T_2c5e5_row1_col5, #T_2c5e5_row1_col6, #T_2c5e5_row2_col0, #T_2c5e5_row2_col2, #T_2c5e5_row2_col3, #T_2c5e5_row2_col4, #T_2c5e5_row3_col0, #T_2c5e5_row3_col1, #T_2c5e5_row3_col2, #T_2c5e5_row3_col3, #T_2c5e5_row3_col4, #T_2c5e5_row3_col5, #T_2c5e5_row3_col6, #T_2c5e5_row4_col0, #T_2c5e5_row4_col1, #T_2c5e5_row4_col2, #T_2c5e5_row4_col3, #T_2c5e5_row4_col4, #T_2c5e5_row4_col5, #T_2c5e5_row4_col6, #T_2c5e5_row5_col0, #T_2c5e5_row5_col1, #T_2c5e5_row5_col2, #T_2c5e5_row5_col3, #T_2c5e5_row5_col4, #T_2c5e5_row5_col5, #T_2c5e5_row5_col6, #T_2c5e5_row6_col0, #T_2c5e5_row6_col1, #T_2c5e5_row6_col2, #T_2c5e5_row6_col3, #T_2c5e5_row6_col4, #T_2c5e5_row6_col5, #T_2c5e5_row6_col6, #T_2c5e5_row7_col0, #T_2c5e5_row7_col1, #T_2c5e5_row7_col2, #T_2c5e5_row7_col3, #T_2c5e5_row7_col4, #T_2c5e5_row7_col5, #T_2c5e5_row7_col6, #T_2c5e5_row8_col0, #T_2c5e5_row8_col1, #T_2c5e5_row8_col2, #T_2c5e5_row8_col3, #T_2c5e5_row8_col4, #T_2c5e5_row8_col5, #T_2c5e5_row8_col6, #T_2c5e5_row9_col0, #T_2c5e5_row9_col1, #T_2c5e5_row9_col2, #T_2c5e5_row9_col3, #T_2c5e5_row9_col4, #T_2c5e5_row9_col5, #T_2c5e5_row9_col6, #T_2c5e5_row10_col0, #T_2c5e5_row10_col1, #T_2c5e5_row10_col2, #T_2c5e5_row10_col3, #T_2c5e5_row10_col4, #T_2c5e5_row10_col5, #T_2c5e5_row10_col6, #T_2c5e5_row11_col0, #T_2c5e5_row11_col1, #T_2c5e5_row11_col2, #T_2c5e5_row11_col3, #T_2c5e5_row11_col4, #T_2c5e5_row11_col5, #T_2c5e5_row11_col6, #T_2c5e5_row12_col0, #T_2c5e5_row12_col1, #T_2c5e5_row12_col2, #T_2c5e5_row12_col3, #T_2c5e5_row12_col4, #T_2c5e5_row12_col5, #T_2c5e5_row12_col6, #T_2c5e5_row13_col0, #T_2c5e5_row13_col1, #T_2c5e5_row13_col2, #T_2c5e5_row13_col3, #T_2c5e5_row13_col4, #T_2c5e5_row13_col5, #T_2c5e5_row13_col6, #T_2c5e5_row14_col0, #T_2c5e5_row14_col1, #T_2c5e5_row14_col2, #T_2c5e5_row14_col3, #T_2c5e5_row14_col4, #T_2c5e5_row14_col5, #T_2c5e5_row14_col6, #T_2c5e5_row15_col0, #T_2c5e5_row15_col1, #T_2c5e5_row15_col2, #T_2c5e5_row15_col3, #T_2c5e5_row15_col4, #T_2c5e5_row15_col5, #T_2c5e5_row15_col6, #T_2c5e5_row16_col0, #T_2c5e5_row16_col1, #T_2c5e5_row16_col2, #T_2c5e5_row16_col3, #T_2c5e5_row16_col4, #T_2c5e5_row16_col5, #T_2c5e5_row16_col6, #T_2c5e5_row17_col0, #T_2c5e5_row17_col1, #T_2c5e5_row17_col2, #T_2c5e5_row17_col3, #T_2c5e5_row17_col4, #T_2c5e5_row17_col5, #T_2c5e5_row17_col6 {
#   text-align: left;
# }
# #T_2c5e5_row0_col2, #T_2c5e5_row0_col3, #T_2c5e5_row0_col4, #T_2c5e5_row2_col1, #T_2c5e5_row2_col5, #T_2c5e5_row2_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_2c5e5_row0_col7, #T_2c5e5_row1_col7, #T_2c5e5_row2_col7, #T_2c5e5_row3_col7, #T_2c5e5_row4_col7, #T_2c5e5_row5_col7, #T_2c5e5_row6_col7, #T_2c5e5_row9_col7, #T_2c5e5_row10_col7, #T_2c5e5_row11_col7, #T_2c5e5_row12_col7, #T_2c5e5_row13_col7, #T_2c5e5_row14_col7, #T_2c5e5_row15_col7, #T_2c5e5_row16_col7, #T_2c5e5_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_2c5e5_row7_col7, #T_2c5e5_row8_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_2c5e5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2c5e5_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_2c5e5_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_2c5e5_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_2c5e5_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_2c5e5_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_2c5e5_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_2c5e5_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_2c5e5_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2c5e5_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_2c5e5_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_2c5e5_row0_col1" class="data row0 col1" >752.5211</td>
#       <td id="T_2c5e5_row0_col2" class="data row0 col2" >2323251.5306</td>
#       <td id="T_2c5e5_row0_col3" class="data row0 col3" >1504.5846</td>
#       <td id="T_2c5e5_row0_col4" class="data row0 col4" >0.9773</td>
#       <td id="T_2c5e5_row0_col5" class="data row0 col5" >0.0808</td>
#       <td id="T_2c5e5_row0_col6" class="data row0 col6" >0.0602</td>
#       <td id="T_2c5e5_row0_col7" class="data row0 col7" >0.2340</td>
#     </tr>
#     <tr>
#       <th id="T_2c5e5_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_2c5e5_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_2c5e5_row1_col1" class="data row1 col1" >739.3780</td>
#       <td id="T_2c5e5_row1_col2" class="data row1 col2" >2622728.7921</td>
#       <td id="T_2c5e5_row1_col3" class="data row1 col3" >1587.7333</td>
#       <td id="T_2c5e5_row1_col4" class="data row1 col4" >0.9744</td>
#       <td id="T_2c5e5_row1_col5" class="data row1 col5" >0.0791</td>
#       <td id="T_2c5e5_row1_col6" class="data row1 col6" >0.0583</td>
#       <td id="T_2c5e5_row1_col7" class="data row1 col7" >0.2170</td>
#     </tr>
#     <tr>
#       <th id="T_2c5e5_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_2c5e5_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_2c5e5_row2_col1" class="data row2 col1" >730.5755</td>
#       <td id="T_2c5e5_row2_col2" class="data row2 col2" >2796401.6305</td>
#       <td id="T_2c5e5_row2_col3" class="data row2 col3" >1631.4912</td>
#       <td id="T_2c5e5_row2_col4" class="data row2 col4" >0.9729</td>
#       <td id="T_2c5e5_row2_col5" class="data row2 col5" >0.0752</td>
#       <td id="T_2c5e5_row2_col6" class="data row2 col6" >0.0556</td>
#       <td id="T_2c5e5_row2_col7" class="data row2 col7" >0.1870</td>
#     </tr>
#     <tr>
#       <th id="T_2c5e5_level0_row3" class="row_heading level0 row3" >gbr</th>
#       <td id="T_2c5e5_row3_col0" class="data row3 col0" >Gradient Boosting Regressor</td>
#       <td id="T_2c5e5_row3_col1" class="data row3 col1" >886.1041</td>
#       <td id="T_2c5e5_row3_col2" class="data row3 col2" >2998925.1656</td>
#       <td id="T_2c5e5_row3_col3" class="data row3 col3" >1715.3560</td>
#       <td id="T_2c5e5_row3_col4" class="data row3 col4" >0.9705</td>
#       <td id="T_2c5e5_row3_col5" class="data row3 col5" >0.1003</td>
#       <td id="T_2c5e5_row3_col6" class="data row3 col6" >0.0757</td>
#       <td id="T_2c5e5_row3_col7" class="data row3 col7" >0.0830</td>
#     </tr>
#     <tr>
#       <th id="T_2c5e5_level0_row4" class="row_heading level0 row4" >dt</th>
#       <td id="T_2c5e5_row4_col0" class="data row4 col0" >Decision Tree Regressor</td>
#       <td id="T_2c5e5_row4_col1" class="data row4 col1" >957.2868</td>
#       <td id="T_2c5e5_row4_col2" class="data row4 col2" >4476289.7858</td>
#       <td id="T_2c5e5_row4_col3" class="data row4 col3" >2074.0758</td>
#       <td id="T_2c5e5_row4_col4" class="data row4 col4" >0.9553</td>
#       <td id="T_2c5e5_row4_col5" class="data row4 col5" >0.1043</td>
#       <td id="T_2c5e5_row4_col6" class="data row4 col6" >0.0757</td>
#       <td id="T_2c5e5_row4_col7" class="data row4 col7" >0.0310</td>
#     </tr>
#     <tr>
#       <th id="T_2c5e5_level0_row5" class="row_heading level0 row5" >lasso</th>
#       <td id="T_2c5e5_row5_col0" class="data row5 col0" >Lasso Regression</td>
#       <td id="T_2c5e5_row5_col1" class="data row5 col1" >2405.1902</td>
#       <td id="T_2c5e5_row5_col2" class="data row5 col2" >14435326.3663</td>
#       <td id="T_2c5e5_row5_col3" class="data row5 col3" >3756.2057</td>
#       <td id="T_2c5e5_row5_col4" class="data row5 col4" >0.8605</td>
#       <td id="T_2c5e5_row5_col5" class="data row5 col5" >0.6055</td>
#       <td id="T_2c5e5_row5_col6" class="data row5 col6" >0.2842</td>
#       <td id="T_2c5e5_row5_col7" class="data row5
# Model Comparison Complete. Best Model: ExtraTreesRegressor

# %%
# 5. ANALYSE MODEL (Diagnostics)
print("\n[STEP 5] Analyzing Model (Plotting Residuals and Prediction Error)...")
# Analyze Residuals Plot (Crucial for Regression)
exp.plot_model(best_model, plot='residuals', save=False)

# Analyze Prediction Error Plot
exp.plot_model(best_model, plot='error', save=False)
# Out:
# [STEP 5] Analyzing Model (Plotting Residuals and Prediction Error)...

# %%
# 6. PREDICTIONS
print("\n[STEP 6] Generating Predictions on Held-Out Test Set...")
# Predict on the held-out test set using OOP method
predictions = exp.predict_model(best_model)
print("\nPredictions on held-out set (first 5 rows):")
# NOTE: Comparing actual 'Price' against the predicted 'prediction_label'
print(predictions[['Price', 'prediction_label']].head())
# Out:
# [STEP 6] Generating Predictions on Held-Out Test Set...
# <style type="text/css">
# </style>
# <table id="T_eaa51">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eaa51_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_eaa51_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_eaa51_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_eaa51_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_eaa51_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_eaa51_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_eaa51_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eaa51_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eaa51_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_eaa51_row0_col1" class="data row0 col1" >737.9485</td>
#       <td id="T_eaa51_row0_col2" class="data row0 col2" >2603005.6324</td>
#       <td id="T_eaa51_row0_col3" class="data row0 col3" >1613.3833</td>
#       <td id="T_eaa51_row0_col4" class="data row0 col4" >0.9760</td>
#       <td id="T_eaa51_row0_col5" class="data row0 col5" >0.0786</td>
#       <td id="T_eaa51_row0_col6" class="data row0 col6" >0.0579</td>
#     </tr>
#   </tbody>
# </table>
# Predictions on held-out set (first 5 rows):
#       Price  prediction_label
# 1293   4186           4212.00
# 5035   5757           5795.00
# 5021   5718           5754.00
# 3879   5112           4447.51
# 3530   3085           3061.81

# %%
# 7. SAVE MODEL
print("\n[STEP 7] Saving Pipeline (MLOps Readiness)...")
# Save the final model and the entire preprocessing pipeline using OOP method
exp.save_model(best_model, 'pycaret_diamond_final_pipeline')
print("\nModel saved successfully as 'pycaret_diamond_final_pipeline.pkl'.")
# Out:
# [STEP 7] Saving Pipeline (MLOps Readiness)...
# Transformation Pipeline and Model Successfully Saved
#
# Model saved successfully as 'pycaret_diamond_final_pipeline.pkl'.

# %% [markdown]
# ## Time Series (Forcasting)

# %%
# Imports
from pycaret.datasets import get_data
from pycaret.time_series import (
    TSForecastingExperiment,
    setup,
    compare_models,
    plot_model,
    finalize_model,
    predict_model,
    save_model
)

# %%
# [STEP 1] Loading the 'airline' dataset
print("[STEP 1] Loading the 'airline' dataset...")
data = get_data('airline')

target_column = 'Number of airline passengers' # Corrected column name for this environment
forecast_horizon = 12 # Predict the next 12 months (one year)
# Out:
# [STEP 1] Loading the 'airline' dataset...
# Period
# 1949-01    112.0
# 1949-02    118.0
# 1949-03    132.0
# 1949-04    129.0
# 1949-05    121.0
# Freq: M, Name: Number of airline passengers, dtype: float64

# %%
# [STEP 2] Initializing Functional API Setup...
s_functional = setup(
    data,
    target=target_column,
    fh=forecast_horizon,
    session_id=7502,
    verbose=True # Ensures setup grid is displayed
)
# Out:
# <style type="text/css">
# #T_62276_row25_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_62276">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_62276_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_62276_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_62276_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_62276_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_62276_row0_col1" class="data row0 col1" >7502</td>
#     </tr>
#     <tr>
#       <th id="T_62276_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_62276_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_62276_row1_col1" class="data row1 col1" >Number of airline passengers</td>
#     </tr>
#     <tr>
#       <th id="T_62276_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_62276_row2_col0" class="data row2 col0" >Approach</td>
#       <td id="T_62276_row2_col1" class="data row2 col1" >Univariate</td>
#     </tr>
#     <tr>
#       <th id="T_62276_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_62276_row3_col0" class="data row3 col0" >Exogenous Variables</td>
#       <td id="T_62276_row3_col1" class="data row3 col1" >Not Present</td>
#     </tr>
#     <tr>
#       <th id="T_62276_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_62276_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_62276_row4_col1" class="data row4 col1" >(144, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_62276_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_62276_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_62276_row5_col1" class="data row5 col1" >(144, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_62276_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_62276_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_62276_row6_col1" class="data row6 col1" >(132, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_62276_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_62276_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_62276_row7_col1" class="data row7 col1" >(12, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_62276_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_62276_row8_col0" class="data row8 col0" >Rows with missing values</td>
#       <td id="T_62276_row8_col1" class="data row8 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_62276_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_62276_row9_col0" class="data row9 col0" >Fold Generator</td>
#       <td id="T_62276_row9_col1" class="data row9 col1" >ExpandingWindowSplitter</td>
#     </tr>
#     <tr>
#       <th id="T_62276_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_62276_row10_col0" class="data row10 col0" >Fold Number</td>
#       <td id="T_62276_row10_col1" class="data row10 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_62276_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_62276_row11_col0" class="data row11 col0" >Enforce Prediction Interval</td>
#       <td id="T_62276_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_62276_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_62276_row12_col0" class="data row12 col0" >Splits used for hyperparameters</td>
#       <td id="T_62276_row12_col1" class="data row12 col1" >all</td>
#     </tr>
#     <tr>
#       <th id="T_62276_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_62276_row13_col0" class="data row13 col0" >User Defined Seasonal Period(s)</td>
#       <td id="T_62276_row13_col1" class="data row13 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_62276_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_62276_row14_col0" class="data row14 col0" >Ignore Seasonality Test</td>
#       <td id="T_62276_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_62276_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_62276_row15_col0" class="data row15 col0" >Seasonality Detection Algo</td>
#       <td id="T_62276_row15_col1" class="data row15 col1" >auto</td>
#     </tr>
#     <tr>
#       <th id="T_62276_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_62276_row16_col0" class="data row16 col0" >Max Period to Consider</td>
#       <td id="T_62276_row16_col1" class="data row16 col1" >60</td>
#     </tr>
#     <tr>
#       <th id="T_62276_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_62276_row17_col0" class="data row17 col0" >Seasonal Period(s) Tested</td>
#       <td id="T_62276_row17_col1" class="data row17 col1" >[12, 24, 36, 11, 48]</td>
#     </tr>
#     <tr>
#       <th id="T_62276_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_62276_row18_col0" class="data row18 col0" >Significant Seasonal Period(s)</td>
#       <td id="T_62276_row18_col1" class="data row18 col1" >[12, 24, 36, 11, 48]</td>
#     </tr>
#     <tr>
#       <th id="T_62276_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_62276_row19_col0" class="data row19 col0" >Significant Seasonal Period(s) without Harmonics</td>
#       <td id="T_62276_row19_col1" class="data row19 col1" >[48, 36, 11]</td>
#     </tr>
#     <tr>
#       <th id="T_62276_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_62276_row20_col0" class="data row20 col0" >Remove Harmonics</td>
#       <td id="T_62276_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_62276_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_62276_row21_col0" class="data row21 col0" >Harmonics Order Method</td>
#       <td id="T_62276_row21_col1" class="data row21 col1" >harmonic_max</td>
#     </tr>
#     <tr>
#       <th id="T_62276_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_62276_row22_col0" class="data row22 col0" >Num Seasonalities to Use</td>
#       <td id="T_62276_row22_col1" class="data row22 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_62276_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_62276_row23_col0" class="data row23 col0" >All Seasonalities to Use</td>
#       <td id="T_62276_row23_col1" class="data row23 col1" >[12]</td>
#     </tr>
#     <tr>
#       <th id="T_62276_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_62276_row24_col0" class="data row24 col0" >Primary Seasonality</td>
#       <td id="T_62276_row24_col1" class="data row24 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_62276_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_62276_row25_col0" class="data row25 col0" >Seasonality Present</td>
#       <td id="T_62276_row25_col1" class="data row25 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_62276_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_62276_row26_col0" class="data row26 col0" >Seasonality Type</td>
#       <td id="T_62276_row26_col1" class="data row26 col1" >mul</td>
#     </tr>
#     <tr>
#       <th id="T_62276_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_62276_row27_col0" class="data row27 col0" >Target Strictly Positive</td>
#       <td id="T_62276_row27_col1" class="data row27 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_62276_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_62276_row28_col0" class="data row28 col0" >Target White Noise</td>
#       <td id="T_62276_row28_col1" class="data row28 col1" >No</td>
#     </tr>
#     <tr>
#       <th id="T_62276_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_62276_row29_col0" class="data row29 col0" >Recommended d</td>
#       <td id="T_62276_row29_col1" class="data row29 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="

# %%
# [STEP 3] Initializing OOP API Setup...
# The OOP API is preferred for stability and structured coding
exp = TSForecastingExperiment()
exp.setup(
    data,
    target=target_column,
    fh=forecast_horizon,
    session_id=7502,
    verbose=True # Ensures setup grid is displayed
)
# Out:
# <style type="text/css">
# #T_9b1da_row25_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9b1da">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9b1da_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_9b1da_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9b1da_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9b1da_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_9b1da_row0_col1" class="data row0 col1" >7502</td>
#     </tr>
#     <tr>
#       <th id="T_9b1da_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9b1da_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_9b1da_row1_col1" class="data row1 col1" >Number of airline passengers</td>
#     </tr>
#     <tr>
#       <th id="T_9b1da_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9b1da_row2_col0" class="data row2 col0" >Approach</td>
#       <td id="T_9b1da_row2_col1" class="data row2 col1" >Univariate</td>
#     </tr>
#     <tr>
#       <th id="T_9b1da_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9b1da_row3_col0" class="data row3 col0" >Exogenous Variables</td>
#       <td id="T_9b1da_row3_col1" class="data row3 col1" >Not Present</td>
#     </tr>
#     <tr>
#       <th id="T_9b1da_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9b1da_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_9b1da_row4_col1" class="data row4 col1" >(144, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_9b1da_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9b1da_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_9b1da_row5_col1" class="data row5 col1" >(144, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_9b1da_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9b1da_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_9b1da_row6_col1" class="data row6 col1" >(132, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_9b1da_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9b1da_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_9b1da_row7_col1" class="data row7 col1" >(12, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_9b1da_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9b1da_row8_col0" class="data row8 col0" >Rows with missing values</td>
#       <td id="T_9b1da_row8_col1" class="data row8 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_9b1da_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9b1da_row9_col0" class="data row9 col0" >Fold Generator</td>
#       <td id="T_9b1da_row9_col1" class="data row9 col1" >ExpandingWindowSplitter</td>
#     </tr>
#     <tr>
#       <th id="T_9b1da_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9b1da_row10_col0" class="data row10 col0" >Fold Number</td>
#       <td id="T_9b1da_row10_col1" class="data row10 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_9b1da_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_9b1da_row11_col0" class="data row11 col0" >Enforce Prediction Interval</td>
#       <td id="T_9b1da_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9b1da_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_9b1da_row12_col0" class="data row12 col0" >Splits used for hyperparameters</td>
#       <td id="T_9b1da_row12_col1" class="data row12 col1" >all</td>
#     </tr>
#     <tr>
#       <th id="T_9b1da_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_9b1da_row13_col0" class="data row13 col0" >User Defined Seasonal Period(s)</td>
#       <td id="T_9b1da_row13_col1" class="data row13 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_9b1da_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_9b1da_row14_col0" class="data row14 col0" >Ignore Seasonality Test</td>
#       <td id="T_9b1da_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9b1da_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_9b1da_row15_col0" class="data row15 col0" >Seasonality Detection Algo</td>
#       <td id="T_9b1da_row15_col1" class="data row15 col1" >auto</td>
#     </tr>
#     <tr>
#       <th id="T_9b1da_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_9b1da_row16_col0" class="data row16 col0" >Max Period to Consider</td>
#       <td id="T_9b1da_row16_col1" class="data row16 col1" >60</td>
#     </tr>
#     <tr>
#       <th id="T_9b1da_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_9b1da_row17_col0" class="data row17 col0" >Seasonal Period(s) Tested</td>
#       <td id="T_9b1da_row17_col1" class="data row17 col1" >[12, 24, 36, 11, 48]</td>
#     </tr>
#     <tr>
#       <th id="T_9b1da_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_9b1da_row18_col0" class="data row18 col0" >Significant Seasonal Period(s)</td>
#       <td id="T_9b1da_row18_col1" class="data row18 col1" >[12, 24, 36, 11, 48]</td>
#     </tr>
#     <tr>
#       <th id="T_9b1da_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_9b1da_row19_col0" class="data row19 col0" >Significant Seasonal Period(s) without Harmonics</td>
#       <td id="T_9b1da_row19_col1" class="data row19 col1" >[48, 36, 11]</td>
#     </tr>
#     <tr>
#       <th id="T_9b1da_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_9b1da_row20_col0" class="data row20 col0" >Remove Harmonics</td>
#       <td id="T_9b1da_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9b1da_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_9b1da_row21_col0" class="data row21 col0" >Harmonics Order Method</td>
#       <td id="T_9b1da_row21_col1" class="data row21 col1" >harmonic_max</td>
#     </tr>
#     <tr>
#       <th id="T_9b1da_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_9b1da_row22_col0" class="data row22 col0" >Num Seasonalities to Use</td>
#       <td id="T_9b1da_row22_col1" class="data row22 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_9b1da_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_9b1da_row23_col0" class="data row23 col0" >All Seasonalities to Use</td>
#       <td id="T_9b1da_row23_col1" class="data row23 col1" >[12]</td>
#     </tr>
#     <tr>
#       <th id="T_9b1da_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_9b1da_row24_col0" class="data row24 col0" >Primary Seasonality</td>
#       <td id="T_9b1da_row24_col1" class="data row24 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_9b1da_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_9b1da_row25_col0" class="data row25 col0" >Seasonality Present</td>
#       <td id="T_9b1da_row25_col1" class="data row25 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9b1da_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_9b1da_row26_col0" class="data row26 col0" >Seasonality Type</td>
#       <td id="T_9b1da_row26_col1" class="data row26 col1" >mul</td>
#     </tr>
#     <tr>
#       <th id="T_9b1da_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_9b1da_row27_col0" class="data row27 col0" >Target Strictly Positive</td>
#       <td id="T_9b1da_row27_col1" class="data row27 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9b1da_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_9b1da_row28_col0" class="data row28 col0" >Target White Noise</td>
#       <td id="T_9b1da_row28_col1" class="data row28 col1" >No</td>
#     </tr>
#     <tr>
#       <th id="T_9b1da_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_9b1da_row29_col0" class="data row29 col0" >Recommended d</td>
#       <td id="T_9b1da_row29_col1" class="data row29 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="

# %%
# [STEP 4] Compare Models (OOP API)
print("\n[STEP 4] Comparing Models to find the best performing algorithm...")
best_model = exp.compare_models(n_select=1)

print(f"\nBest Model Selected: {type(best_model).__name__}")
# Out:
# [STEP 4] Comparing Models to find the best performing algorithm...
# <style type="text/css">
# #T_a7704 th {
#   text-align: left;
# }
# #T_a7704_row0_col0, #T_a7704_row1_col0, #T_a7704_row1_col1, #T_a7704_row1_col2, #T_a7704_row1_col3, #T_a7704_row1_col4, #T_a7704_row1_col5, #T_a7704_row1_col6, #T_a7704_row1_col7, #T_a7704_row2_col0, #T_a7704_row2_col1, #T_a7704_row2_col2, #T_a7704_row2_col3, #T_a7704_row2_col4, #T_a7704_row2_col5, #T_a7704_row2_col6, #T_a7704_row2_col7, #T_a7704_row3_col0, #T_a7704_row3_col1, #T_a7704_row3_col2, #T_a7704_row3_col3, #T_a7704_row3_col4, #T_a7704_row3_col5, #T_a7704_row3_col6, #T_a7704_row3_col7, #T_a7704_row4_col0, #T_a7704_row4_col1, #T_a7704_row4_col2, #T_a7704_row4_col3, #T_a7704_row4_col4, #T_a7704_row4_col5, #T_a7704_row4_col6, #T_a7704_row4_col7, #T_a7704_row5_col0, #T_a7704_row5_col1, #T_a7704_row5_col2, #T_a7704_row5_col3, #T_a7704_row5_col4, #T_a7704_row5_col5, #T_a7704_row5_col6, #T_a7704_row5_col7, #T_a7704_row6_col0, #T_a7704_row6_col1, #T_a7704_row6_col2, #T_a7704_row6_col3, #T_a7704_row6_col4, #T_a7704_row6_col5, #T_a7704_row6_col6, #T_a7704_row6_col7, #T_a7704_row7_col0, #T_a7704_row7_col1, #T_a7704_row7_col2, #T_a7704_row7_col3, #T_a7704_row7_col4, #T_a7704_row7_col5, #T_a7704_row7_col6, #T_a7704_row7_col7, #T_a7704_row8_col0, #T_a7704_row8_col1, #T_a7704_row8_col2, #T_a7704_row8_col3, #T_a7704_row8_col4, #T_a7704_row8_col5, #T_a7704_row8_col6, #T_a7704_row8_col7, #T_a7704_row9_col0, #T_a7704_row9_col1, #T_a7704_row9_col2, #T_a7704_row9_col3, #T_a7704_row9_col4, #T_a7704_row9_col5, #T_a7704_row9_col6, #T_a7704_row9_col7, #T_a7704_row10_col0, #T_a7704_row10_col1, #T_a7704_row10_col2, #T_a7704_row10_col3, #T_a7704_row10_col4, #T_a7704_row10_col5, #T_a7704_row10_col6, #T_a7704_row10_col7, #T_a7704_row11_col0, #T_a7704_row11_col1, #T_a7704_row11_col2, #T_a7704_row11_col3, #T_a7704_row11_col4, #T_a7704_row11_col5, #T_a7704_row11_col6, #T_a7704_row11_col7, #T_a7704_row12_col0, #T_a7704_row12_col1, #T_a7704_row12_col2, #T_a7704_row12_col3, #T_a7704_row12_col4, #T_a7704_row12_col5, #T_a7704_row12_col6, #T_a7704_row12_col7, #T_a7704_row13_col0, #T_a7704_row13_col1, #T_a7704_row13_col2, #T_a7704_row13_col3, #T_a7704_row13_col4, #T_a7704_row13_col5, #T_a7704_row13_col6, #T_a7704_row13_col7, #T_a7704_row14_col0, #T_a7704_row14_col1, #T_a7704_row14_col2, #T_a7704_row14_col3, #T_a7704_row14_col4, #T_a7704_row14_col5, #T_a7704_row14_col6, #T_a7704_row14_col7, #T_a7704_row15_col0, #T_a7704_row15_col1, #T_a7704_row15_col2, #T_a7704_row15_col3, #T_a7704_row15_col4, #T_a7704_row15_col5, #T_a7704_row15_col6, #T_a7704_row15_col7, #T_a7704_row16_col0, #T_a7704_row16_col1, #T_a7704_row16_col2, #T_a7704_row16_col3, #T_a7704_row16_col4, #T_a7704_row16_col5, #T_a7704_row16_col6, #T_a7704_row16_col7, #T_a7704_row17_col0, #T_a7704_row17_col1, #T_a7704_row17_col2, #T_a7704_row17_col3, #T_a7704_row17_col4, #T_a7704_row17_col5, #T_a7704_row17_col6, #T_a7704_row17_col7, #T_a7704_row18_col0, #T_a7704_row18_col1, #T_a7704_row18_col2, #T_a7704_row18_col3, #T_a7704_row18_col4, #T_a7704_row18_col5, #T_a7704_row18_col6, #T_a7704_row18_col7, #T_a7704_row19_col0, #T_a7704_row19_col1, #T_a7704_row19_col2, #T_a7704_row19_col3, #T_a7704_row19_col4, #T_a7704_row19_col5, #T_a7704_row19_col6, #T_a7704_row19_col7, #T_a7704_row20_col0, #T_a7704_row20_col1, #T_a7704_row20_col2, #T_a7704_row20_col3, #T_a7704_row20_col4, #T_a7704_row20_col5, #T_a7704_row20_col6, #T_a7704_row20_col7, #T_a7704_row21_col0, #T_a7704_row21_col1, #T_a7704_row21_col2, #T_a7704_row21_col3, #T_a7704_row21_col4, #T_a7704_row21_col5, #T_a7704_row21_col6, #T_a7704_row21_col7, #T_a7704_row22_col0, #T_a7704_row22_col1, #T_a7704_row22_col2, #T_a7704_row22_col3, #T_a7704_row22_col4, #T_a7704_row22_col5, #T_a7704_row22_col6, #T_a7704_row22_col7, #T_a7704_row23_col0, #T_a7704_row23_col1, #T_a7704_row23_col2, #T_a7704_row23_col3, #T_a7704_row23_col4, #T_a7704_row23_col5, #T_a7704_row23_col6, #T_a7704_row23_col7, #T_a7704_row24_col0, #T_a7704_row24_col1, #T_a7704_row24_col2, #T_a7704_row24_col3, #T_a7704_row24_col4, #T_a7704_row24_col5, #T_a7704_row24_col6, #T_a7704_row24_col7, #T_a7704_row25_col0, ...
#   text-align: left;
# }
# #T_a7704_row0_col1, #T_a7704_row0_col2, #T_a7704_row0_col3, #T_a7704_row0_col4, #T_a7704_row0_col5, #T_a7704_row0_col6, #T_a7704_row0_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_a7704_row0_col8, #T_a7704_row1_col8, #T_a7704_row2_col8, #T_a7704_row3_col8, #T_a7704_row4_col8, #T_a7704_row5_col8, #T_a7704_row6_col8, #T_a7704_row7_col8, #T_a7704_row8_col8, #T_a7704_row9_col8, #T_a7704_row10_col8, #T_a7704_row11_col8, #T_a7704_row12_col8, #T_a7704_row13_col8, #T_a7704_row14_col8, #T_a7704_row15_col8, #T_a7704_row16_col8, #T_a7704_row17_col8, #T_a7704_row18_col8, #T_a7704_row19_col8, #T_a7704_row20_col8, #T_a7704_row21_col8, #T_a7704_row22_col8, #T_a7704_row24_col8, #T_a7704_row25_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_a7704_row23_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_a7704">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a7704_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a7704_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_a7704_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_a7704_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_a7704_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_a7704_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_a7704_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#       <th id="T_a7704_level0_col7" class="col_heading level0 col7" >R2</th>
#       <th id="T_a7704_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7704_level0_row0" class="row_heading level0 row0" >exp_smooth</th>
#       <td id="T_a7704_row0_col0" class="data row0 col0" >Exponential Smoothing</td>
#       <td id="T_a7704_row0_col1" class="data row0 col1" >0.5716</td>
#       <td id="T_a7704_row0_col2" class="data row0 col2" >0.5997</td>
#       <td id="T_a7704_row0_col3" class="data row0 col3" >16.7774</td>
#       <td id="T_a7704_row0_col4" class="data row0 col4" >19.7960</td>
#       <td id="T_a7704_row0_col5" class="data row0 col5" >0.0422</td>
#       <td id="T_a7704_row0_col6" class="data row0 col6" >0.0427</td>
#       <td id="T_a7704_row0_col7" class="data row0 col7" >0.8954</td>
#       <td id="T_a7704_row0_col8" class="data row0 col8" >0.0767</td>
#     </tr>
#     <tr>
#       <th id="T_a7704_level0_row1" class="row_heading level0 row1" >ets</th>
#       <td id="T_a7704_row1_col0" class="data row1 col0" >ETS</td>
#       <td id="T_a7704_row1_col1" class="data row1 col1" >0.5865</td>
#       <td id="T_a7704_row1_col2" class="data row1 col2" >0.6156</td>
#       <td id="T_a7704_row1_col3" class="data row1 col3" >17.2147</td>
#       <td id="T_a7704_row1_col4" class="data row1 col4" >20.3200</td>
#       <td id="T_a7704_row1_col5" class="data row1 col5" >0.0434</td>
#       <td id="T_a7704_row1_col6" class="data row1 col6" >0.0439</td>
#       <td id="T_a7704_row1_col7" class="data row1 col7" >0.8901</td>
#       <td id="T_a7704_row1_col8" class="data row1 col8" >0.0933</td>
#     </tr>
#     <tr>
#       <th id="T_a7704_level0_row2" class="row_heading level0 row2" >et_cds_dt</th>
#       <td id="T_a7704_row2_col0" class="data row2 col0" >Extra Trees w/ Cond. Deseasonalize & Detrending</td>
#       <td id="T_a7704_row2_col1" class="data row2 col1" >0.6751</td>
#       <td id="T_a7704_row2_col2" class="data row2 col2" >0.7354</td>
#       <td id="T_a7704_row2_col3" class="data row2 col3" >19.9040</td>
#       <td id="T_a7704_row2_col4" class="data row2 col4" >24.3274</td>
#       <td id="T_a7704_row2_col5" class="data row2 col5" >0.0497</td>
#       <td id="T_a7704_row2_col6" class="data row2 col6" >0.0496</td>
# Best Model Selected: ExponentialSmoothing

# %%
# [STEP 5] Analyze Model (Plot Forecast)
print("\n[STEP 5] Analyzing Model: Plotting 12-step forecast...")
# This plot will show the historical trend and the predicted future values
exp.plot_model(best_model, plot='forecast')
# Out:
# [STEP 5] Analyzing Model: Plotting 12-step forecast...

# %%
# [STEP 6] Predictions (Forecast)
print("\n[STEP 6] Making Predictions on the forecast horizon (12 steps)...")
predictions = exp.predict_model(best_model)
print("Forecasted Values (first 5):")
print(predictions.head())
# Out:
# [STEP 6] Making Predictions on the forecast horizon (12 steps)...
# <style type="text/css">
# </style>
# <table id="T_0baa9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0baa9_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0baa9_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_0baa9_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_0baa9_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_0baa9_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_0baa9_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_0baa9_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#       <th id="T_0baa9_level0_col7" class="col_heading level0 col7" >R2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0baa9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0baa9_row0_col0" class="data row0 col0" >Exponential Smoothing</td>
#       <td id="T_0baa9_row0_col1" class="data row0 col1" >0.3384</td>
#       <td id="T_0baa9_row0_col2" class="data row0 col2" >0.4576</td>
#       <td id="T_0baa9_row0_col3" class="data row0 col3" >10.3031</td>
#       <td id="T_0baa9_row0_col4" class="data row0 col4" >15.8104</td>
#       <td id="T_0baa9_row0_col5" class="data row0 col5" >0.0221</td>
#       <td id="T_0baa9_row0_col6" class="data row0 col6" >0.0216</td>
#       <td id="T_0baa9_row0_col7" class="data row0 col7" >0.9549</td>
#     </tr>
#   </tbody>
# </table>
# Forecasted Values (first 5):
#            y_pred
# 1960-01  417.2853
# 1960-02  394.0617
# 1960-03  462.4440
# 1960-04  448.5977
# 1960-05  471.8700

# %%
# [STEP 7] Finalize and Save Model (MLOps Readiness)
print("\n[STEP 7] Finalizing model and saving pipeline...")
# Finalize trains the best model on the entire dataset
final_pipeline = exp.finalize_model(best_model)
exp.save_model(final_pipeline, 'time_series_airline_pipeline')

print("\nPipeline saved successfully!")
# Out:
# [STEP 7] Finalizing model and saving pipeline...
# Transformation Pipeline and Model Successfully Saved
#
# Pipeline saved successfully!

# %% [markdown]
# ## Clustering Module

# %%
# Imports
from pycaret.datasets import get_data
from pycaret.clustering import (
    ClusteringExperiment,
    setup,
    create_model,
    assign_model,
    plot_model,
    save_model
)

print("--- Structured CLUSTERING Workflow ---")
# Out:
# --- Structured CLUSTERING Workflow ---

# %%
# [STEP 1] Loading the 'jewellery' dataset
print("[STEP 1] Loading the 'jewellery' dataset...")
data = get_data('jewellery')
# Out:
# [STEP 1] Loading the 'jewellery' dataset...
#    Age  Income  SpendingScore       Savings
# 0   58   77769       0.791329   6559.829923
# 1   59   81799       0.791082   5417.661426
# 2   62   74751       0.702657   9258.992965
# 3   59   74373       0.765680   7346.334504
# 4   87   17760       0.348778  16869.507130

# %%
# [STEP 2] Initializing Functional API Setup...
# For clustering, no target variable is defined.
s_functional = setup(
    data,
    session_id=7502,
    verbose=True # Ensures setup grid is displayed
)
# Out:
# <style type="text/css">
# #T_b67fb_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b67fb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b67fb_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b67fb_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b67fb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b67fb_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_b67fb_row0_col1" class="data row0 col1" >7502</td>
#     </tr>
#     <tr>
#       <th id="T_b67fb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b67fb_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_b67fb_row1_col1" class="data row1 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_b67fb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b67fb_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_b67fb_row2_col1" class="data row2 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_b67fb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b67fb_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_b67fb_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_b67fb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b67fb_row4_col0" class="data row4 col0" >Preprocess</td>
#       <td id="T_b67fb_row4_col1" class="data row4 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b67fb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b67fb_row5_col0" class="data row5 col0" >Imputation type</td>
#       <td id="T_b67fb_row5_col1" class="data row5 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_b67fb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b67fb_row6_col0" class="data row6 col0" >Numeric imputation</td>
#       <td id="T_b67fb_row6_col1" class="data row6 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_b67fb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b67fb_row7_col0" class="data row7 col0" >Categorical imputation</td>
#       <td id="T_b67fb_row7_col1" class="data row7 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_b67fb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b67fb_row8_col0" class="data row8 col0" >CPU Jobs</td>
#       <td id="T_b67fb_row8_col1" class="data row8 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_b67fb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b67fb_row9_col0" class="data row9 col0" >Use GPU</td>
#       <td id="T_b67fb_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b67fb_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b67fb_row10_col0" class="data row10 col0" >Log Experiment</td>
#       <td id="T_b67fb_row10_col1" class="data row10 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b67fb_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_b67fb_row11_col0" class="data row11 col0" >Experiment Name</td>
#       <td id="T_b67fb_row11_col1" class="data row11 col1" >cluster-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_b67fb_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_b67fb_row12_col0" class="data row12 col0" >USI</td>
#       <td id="T_b67fb_row12_col1" class="data row12 col1" >cab8</td>
#     </tr>
#   </tbody>
# </table>

# %%
# [STEP 3] Initializing OOP API Setup...
exp = ClusteringExperiment()
exp.setup(
    data,
    session_id=7502,
    verbose=True # Ensures setup grid is displayed
)
# Out:
# <style type="text/css">
# #T_eb795_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_eb795">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eb795_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_eb795_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb795_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eb795_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_eb795_row0_col1" class="data row0 col1" >7502</td>
#     </tr>
#     <tr>
#       <th id="T_eb795_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_eb795_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_eb795_row1_col1" class="data row1 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_eb795_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_eb795_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_eb795_row2_col1" class="data row2 col1" >(505, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_eb795_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_eb795_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_eb795_row3_col1" class="data row3 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_eb795_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_eb795_row4_col0" class="data row4 col0" >Preprocess</td>
#       <td id="T_eb795_row4_col1" class="data row4 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_eb795_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_eb795_row5_col0" class="data row5 col0" >Imputation type</td>
#       <td id="T_eb795_row5_col1" class="data row5 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_eb795_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_eb795_row6_col0" class="data row6 col0" >Numeric imputation</td>
#       <td id="T_eb795_row6_col1" class="data row6 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_eb795_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_eb795_row7_col0" class="data row7 col0" >Categorical imputation</td>
#       <td id="T_eb795_row7_col1" class="data row7 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_eb795_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_eb795_row8_col0" class="data row8 col0" >CPU Jobs</td>
#       <td id="T_eb795_row8_col1" class="data row8 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_eb795_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_eb795_row9_col0" class="data row9 col0" >Use GPU</td>
#       <td id="T_eb795_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_eb795_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_eb795_row10_col0" class="data row10 col0" >Log Experiment</td>
#       <td id="T_eb795_row10_col1" class="data row10 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_eb795_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_eb795_row11_col0" class="data row11 col0" >Experiment Name</td>
#       <td id="T_eb795_row11_col1" class="data row11 col1" >cluster-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_eb795_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_eb795_row12_col0" class="data row12 col0" >USI</td>
#       <td id="T_eb795_row12_col1" class="data row12 col1" >0d4f</td>
#     </tr>
#   </tbody>
# </table>

# %%
# [STEP 4] Create Model (OOP API)
print("\n[STEP 4] Creating K-Means Model for customer segmentation...")
# We choose K-Means and request 4 clusters (segments)
k_means = exp.create_model('kmeans', num_clusters=4)

print(f"\nModel Selected: {type(k_means).__name__}")
# Out:
# [STEP 4] Creating K-Means Model for customer segmentation...
# <style type="text/css">
# </style>
# <table id="T_64907">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_64907_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_64907_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_64907_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_64907_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_64907_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_64907_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64907_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_64907_row0_col0" class="data row0 col0" >0.7217</td>
#       <td id="T_64907_row0_col1" class="data row0 col1" >5009.6748</td>
#       <td id="T_64907_row0_col2" class="data row0 col2" >0.4082</td>
#       <td id="T_64907_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_64907_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_64907_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Model Selected: KMeans

# %%
# [STEP 5] Analyze Model (Plot Diagnostics)
print("\n[STEP 5] Analyzing Model: Plotting t-SNE projection of clusters...")
# t-SNE is a common plot to visualize high-dimensional clusters
exp.plot_model(k_means, plot='tsne')
# Out:
# [STEP 5] Analyzing Model: Plotting t-SNE projection of clusters...

# %%
# [STEP 6] Assign Cluster Labels
print("\n[STEP 6] Assigning Cluster Labels back to the original data...")
# Adds a new column ('Cluster') to the data, identifying the segment for each row
data_with_clusters = exp.assign_model(k_means)
print("Data with Clusters (first 5 rows):")
print(data_with_clusters.head())
# Out:
# [STEP 6] Assigning Cluster Labels back to the original data...
# Data with Clusters (first 5 rows):
#    Age  Income  SpendingScore       Savings    Cluster
# 0   58   77769       0.791329   6559.830078  Cluster 2
# 1   59   81799       0.791082   5417.661621  Cluster 2
# 2   62   74751       0.702657   9258.993164  Cluster 2
# 3   59   74373       0.765680   7346.334473  Cluster 2
# 4   87   17760       0.348778  16869.507812  Cluster 0

# %%
# [STEP 7] Save Model (MLOps Readiness)
print("\n[STEP 7] Saving clustering model and preprocessing pipeline...")
# Saves the final model and the entire preprocessing pipeline for consistent segmenting of new data
exp.save_model(k_means, 'clustering_jewellery_pipeline')

print("\nPipeline saved successfully!")
# Out:
# [STEP 7] Saving clustering model and preprocessing pipeline...
# Transformation Pipeline and Model Successfully Saved
#
# Pipeline saved successfully!

# %% [markdown]
# ## Anamoly Detection

# %%
# Imports
from pycaret.datasets import get_data
from pycaret.anomaly import (
    AnomalyExperiment,
    setup,
    create_model,
    assign_model,
    plot_model,
    save_model
)

print("--- ANOMALY DETECTION Workflow ---")
# Out:
# --- ANOMALY DETECTION Workflow ---

# %%
# [STEP 1] Loading the 'kiva' dataset
print("[STEP 1] Loading the 'kiva' dataset...")
# Kiva data is often used for detecting unusual/fraudulent loan requests
data = get_data('kiva')
# Out:
# [STEP 1] Loading the 'kiva' dataset...
#               country                                                 en  \
# 0  Dominican Republic  "Banco Esperanza" is a group of 10 women looki...
# 1  Dominican Republic  "Caminemos Hacia Adelante" or "Walking Forward...
# 2  Dominican Republic  "Creciendo Por La Union" is a group of 10 peop...
# 3  Dominican Republic  "Cristo Vive" ("Christ lives" is a group of 10...
# 4  Dominican Republic  "Cristo Vive" is a large group of 35 people, 2...
#
#   gender  loan_amount nonpayment    sector  status
# 0      F         1225    partner    Retail       0
# 1      F         1975     lender  Clothing       0
# 2      F         2175    partner  Clothing       0
# 3      F         1425    partner  Clothing       0
# 4      F         4025    partner      Food       0

# %%
# [STEP 2] Initializing Functional API Setup...
# For Anomaly Detection, no target variable is defined.
print("[STEP 2] Initializing Functional API Setup for Anomaly Detection...")
s_functional = setup(
    data,
    session_id=7502,
    verbose=True # Ensures setup grid is displayed
)
# Out:
# [STEP 2] Initializing Functional API Setup for Anomaly Detection...
# <style type="text/css">
# #T_a9626_row5_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a9626">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9626_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_a9626_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9626_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a9626_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_a9626_row0_col1" class="data row0 col1" >7502</td>
#     </tr>
#     <tr>
#       <th id="T_a9626_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a9626_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_a9626_row1_col1" class="data row1 col1" >(6818, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_a9626_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a9626_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_a9626_row2_col1" class="data row2 col1" >(6818, 6835)</td>
#     </tr>
#     <tr>
#       <th id="T_a9626_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a9626_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_a9626_row3_col1" class="data row3 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_a9626_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a9626_row4_col0" class="data row4 col0" >Categorical features</td>
#       <td id="T_a9626_row4_col1" class="data row4 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_a9626_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a9626_row5_col0" class="data row5 col0" >Preprocess</td>
#       <td id="T_a9626_row5_col1" class="data row5 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a9626_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a9626_row6_col0" class="data row6 col0" >Imputation type</td>
#       <td id="T_a9626_row6_col1" class="data row6 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_a9626_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a9626_row7_col0" class="data row7 col0" >Numeric imputation</td>
#       <td id="T_a9626_row7_col1" class="data row7 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_a9626_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a9626_row8_col0" class="data row8 col0" >Categorical imputation</td>
#       <td id="T_a9626_row8_col1" class="data row8 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_a9626_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a9626_row9_col0" class="data row9 col0" >Maximum one-hot encoding</td>
#       <td id="T_a9626_row9_col1" class="data row9 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_a9626_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a9626_row10_col0" class="data row10 col0" >Encoding method</td>
#       <td id="T_a9626_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a9626_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a9626_row11_col0" class="data row11 col0" >CPU Jobs</td>
#       <td id="T_a9626_row11_col1" class="data row11 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_a9626_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a9626_row12_col0" class="data row12 col0" >Use GPU</td>
#       <td id="T_a9626_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a9626_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a9626_row13_col0" class="data row13 col0" >Log Experiment</td>
#       <td id="T_a9626_row13_col1" class="data row13 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a9626_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a9626_row14_col0" class="data row14 col0" >Experiment Name</td>
#       <td id="T_a9626_row14_col1" class="data row14 col1" >anomaly-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_a9626_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_a9626_row15_col0" class="data row15 col0" >USI</td>
#       <td id="T_a9626_row15_col1" class="data row15 col1" >28f1</td>
#     </tr>
#   </tbody>
# </table>

# %%
# [STEP 3] Initializing OOP API Setup...
exp = AnomalyExperiment()
exp.setup(
    data,
    session_id=7502,
    verbose=True # Ensures setup grid is displayed
)
# Out:
# <style type="text/css">
# #T_27cd8_row5_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_27cd8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_27cd8_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_27cd8_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_27cd8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_27cd8_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_27cd8_row0_col1" class="data row0 col1" >7502</td>
#     </tr>
#     <tr>
#       <th id="T_27cd8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_27cd8_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_27cd8_row1_col1" class="data row1 col1" >(6818, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_27cd8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_27cd8_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_27cd8_row2_col1" class="data row2 col1" >(6818, 6835)</td>
#     </tr>
#     <tr>
#       <th id="T_27cd8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_27cd8_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_27cd8_row3_col1" class="data row3 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_27cd8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_27cd8_row4_col0" class="data row4 col0" >Categorical features</td>
#       <td id="T_27cd8_row4_col1" class="data row4 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_27cd8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_27cd8_row5_col0" class="data row5 col0" >Preprocess</td>
#       <td id="T_27cd8_row5_col1" class="data row5 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_27cd8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_27cd8_row6_col0" class="data row6 col0" >Imputation type</td>
#       <td id="T_27cd8_row6_col1" class="data row6 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_27cd8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_27cd8_row7_col0" class="data row7 col0" >Numeric imputation</td>
#       <td id="T_27cd8_row7_col1" class="data row7 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_27cd8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_27cd8_row8_col0" class="data row8 col0" >Categorical imputation</td>
#       <td id="T_27cd8_row8_col1" class="data row8 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_27cd8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_27cd8_row9_col0" class="data row9 col0" >Maximum one-hot encoding</td>
#       <td id="T_27cd8_row9_col1" class="data row9 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_27cd8_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_27cd8_row10_col0" class="data row10 col0" >Encoding method</td>
#       <td id="T_27cd8_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_27cd8_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_27cd8_row11_col0" class="data row11 col0" >CPU Jobs</td>
#       <td id="T_27cd8_row11_col1" class="data row11 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_27cd8_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_27cd8_row12_col0" class="data row12 col0" >Use GPU</td>
#       <td id="T_27cd8_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_27cd8_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_27cd8_row13_col0" class="data row13 col0" >Log Experiment</td>
#       <td id="T_27cd8_row13_col1" class="data row13 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_27cd8_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_27cd8_row14_col0" class="data row14 col0" >Experiment Name</td>
#       <td id="T_27cd8_row14_col1" class="data row14 col1" >anomaly-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_27cd8_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_27cd8_row15_col0" class="data row15 col0" >USI</td>
#       <td id="T_27cd8_row15_col1" class="data row15 col1" >a60c</td>
#     </tr>
#   </tbody>
# </table>

# %%
# [STEP 4] Create Model (OOP API)
print("\n[STEP 4] Creating Isolation Forest Model (iforest) for anomaly detection...")
# Isolation Forest is a robust, common model for outlier detection
iforest = exp.create_model('iforest', fraction=0.05) # fraction=0.05 tells it to look for 5% anomalies

print(f"\nModel Selected: {type(iforest).__name__}")
# Out:
# [STEP 4] Creating Isolation Forest Model (iforest) for anomaly detection...
# Model Selected: IForest

# %%
# [STEP 5] Analyze Model (Plot Diagnostics)
print("\n[STEP 5] Analyzing Model: Plotting t-SNE projection of anomalies...")
# t-SNE helps visualize the outliers separated from the main cluster
exp.plot_model(iforest, plot='tsne')
# Out:
# [STEP 5] Analyzing Model: Plotting t-SNE projection of anomalies...

# %%
# [STEP 6] Assign Anomaly Labels
print("\n[STEP 6] Assigning Anomaly Labels and Scores to the original data...")
# Adds two new columns: 'Anomaly' (1 or 0) and 'Anomaly_Score'
data_with_anomalies = exp.assign_model(iforest)

print("Data with Anomaly Labels (first 5 rows):")
print(data_with_anomalies[['Anomaly', 'Anomaly_Score']].head())
print("\nTotal anomalies found:", data_with_anomalies['Anomaly'].sum())
# Out:
# [STEP 6] Assigning Anomaly Labels and Scores to the original data...
# Data with Anomaly Labels (first 5 rows):
#    Anomaly  Anomaly_Score
# 0        0      -0.006017
# 1        0      -0.002320
# 2        1       0.001151
# 3        0      -0.003480
# 4        0      -0.001540
#
# Total anomalies found: 340

# %%
# [STEP 7] Save Model (MLOps Readiness)
print("\n[STEP 7] Saving anomaly detector and preprocessing pipeline...")
exp.save_model(iforest, 'anomaly_kiva_pipeline')

print("\nPipeline saved successfully!")
# Out:
# [STEP 7] Saving anomaly detector and preprocessing pipeline...
# Transformation Pipeline and Model Successfully Saved
#
# Pipeline saved successfully!
